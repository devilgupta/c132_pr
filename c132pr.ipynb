# %% [markdown]
# <a href="https://colab.research.google.com/github/devilgupta/c132_pr/blob/main/c132pr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-6d922376-8fdc-407b-a2ee-b743f3490ed8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d922376-8fdc-407b-a2ee-b743f3490ed8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving starwithgravity.csv to starwithgravity.csv

# %%
import pandas as pd
df=pd.read_csv("starwithgravity.csv")
df.head()
# Out:
#    Unnamed: 0       Star_name     Distance  Mass  Radius     Gravity
# 0           0             Sun  0.000015813   1.0    1.00  274.269161
# 1           1          Sirius          8.6   2.1    1.71  196.971800
# 2           2         Canopus          310  15.0   71.00    0.816115
# 3           3  Alpha Centauri          4.4   1.1    1.20  209.511165
# 4           4        Arcturus           37   1.1   26.00    0.446296

# %%
mass=df["Mass"].tolist()
distance=df["Distance"].tolist()
radius=df["Radius"].tolist()
gravity=df["Gravity"].tolist()

import matplotlib.pyplot as plt
plt.plot(radius,mass)
plt.title("radius and mass of the star")
plt.xlabel("Radius")
plt.ylabel("Mass")
plt.show()

# %%
plt.plot(gravity,mass)
plt.title("gravity and mass of the star")
plt.xlabel("Gravity")
plt.ylabel("Mass")
plt.show()

# %%
plt.scatter(radius,mass)
plt.title("radius and mass of the star")
plt.xlabel("Radius")
plt.ylabel("Mass")
plt.show()
